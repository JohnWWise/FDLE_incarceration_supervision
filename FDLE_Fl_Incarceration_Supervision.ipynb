# %%
import pandas as pd
data = pd.read_csv('Incarcerationsupervision_00000.csv')

# %%
data.head()
# Out:
#    INCARCERATION_SUPERVISION_ID                 UNIQUE_CORRELATION_ID  \
# 0                        463271  6738b17c-16b3-44c1-b7f6-be1f6e0dd28c
# 1                        463322  5fd7e6f8-416d-4e3a-9392-7cdcc0fa5e25
# 2                        463378  922702a7-c8e1-4915-ae78-8d343cf1b61e
# 3                        463387  a6ea70a9-1610-4bc0-b4b6-ed507c4c9cad
# 4                        463430  08ccd0db-2c36-4f84-b127-dad32e02efc1
#
#    OWNER_ORI  PERSON_ID  MDM_PERSON_ID RACE_CODE SEX_CODE  \
# 0  FL037275C   13453329         766862     Black     Male
# 1  FL037275C   13453380         712707     Black     Male
# 2  FL037275C   13453436        1084829     Black     Male
# 3  FL037275C   13453444        1239320     White     Male
# 4  FL037275C   13453489          65655     White   Female
#
#            ETHNICITY_CODE       CUSTODY_ADMISSION_DATE SUPERVISION_BEGIN_DATE  \
# 0  Not Hispanic or Latino  2021-08-17 00:00:00.0000000                    NaN
# ...
